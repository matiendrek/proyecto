# %%
import pandas as pd
import numpy as np 
import requests as rq

# %%
# Descargo el archivo json desde guthub.

url = "https://raw.githubusercontent.com/HX-FAshur/PI01_DATA05/main/Datasets/netflix_titles.json" 


f = rq.get(url)

data = f.json()

# Convierto el archivo json de netflix a un dataframe.

netflix = pd.DataFrame(data)

# %%
# Renombro las columnas del dataframe de netxlix.

netflix.rename(columns= {"type": "tipo", "title": "titulo", "cast": "emitir",
 "country": "pais", "date_added": "fecha_agregada",
"release_year": "año_de_lanzamiento", "duration": "duracion", "listed_in": "genero",
 "description": "descripcion"}, inplace=True)

# %%
# Descargo los datasets en formato csv que faltaban.

url_hulu = pd.read_csv("https://raw.githubusercontent.com/HX-FAshur/PI01_DATA05/main/Datasets/hulu_titles.csv")

url_amazon = pd.read_csv("https://raw.githubusercontent.com/HX-FAshur/PI01_DATA05/main/Datasets/amazon_prime_titles.csv")

url_disney = pd.read_csv("https://raw.githubusercontent.com/HX-FAshur/PI01_DATA05/main/Datasets/disney_plus_titles.csv")

# %%
# Convierto los archivos csv en dataframes.

hulu = pd.DataFrame(url_hulu)
amazon = pd.DataFrame(url_amazon)
disney = pd.DataFrame(url_disney)

# %%
# Renombro las columnas del dataframe de hulu.

hulu.rename(columns= {"type": "tipo", "title": "titulo", "cast": "emitir",
 "country": "pais", "date_added": "fecha_agregada",
"release_year": "año_de_lanzamiento", "duration": "duracion", "listed_in": "genero",
 "description": "descripcion"}, inplace=True)

# %%
# Renombro las columnas del dataframe de amazon.

amazon.rename(columns= {"type": "tipo", "title": "titulo", "cast": "emitir",
 "country": "pais", "date_added": "fecha_agregada",
"release_year": "año_de_lanzamiento", "duration": "duracion", "listed_in": "genero",
 "description": "descripcion"}, inplace=True)

# %%
# Renombro las columnas del dataframe de disney.

disney.rename(columns= {"type": "tipo", "title": "titulo", "cast": "emitir",
 "country": "pais", "date_added": "fecha_agregada",
"release_year": "año_de_lanzamiento", "duration": "duracion", "listed_in": "genero",
 "description": "descripcion"}, inplace=True)

# %% [markdown]
# Las consultas a realizar son:
#
# Máxima duración según tipo de film (película/serie), por plataforma y por año: El request debe ser: get_max_duration(año, plataforma, [min o season])
#
# Cantidad de películas y series (separado) por plataforma El request debe ser: get_count_plataform(plataforma)
#
# Cantidad de veces que se repite un género y plataforma con mayor frecuencia del mismo. El request debe ser: get_listedin('genero')
# Como ejemplo de género pueden usar 'comedy', el cuál deberia devolverles un cunt de 2099 para la plataforma de amazon.
#
# Actor que más se repite según plataforma y año. El request debe ser: get_actor(plataforma, año)

# %%
# Elimino las columnas innecesarias

netflix2 = netflix.drop(['pais','fecha_agregada','descripcion'], axis=1)

hulu2 = hulu.drop(['pais','fecha_agregada','descripcion'], axis=1)

amazon2 = amazon.drop(['pais','fecha_agregada','descripcion'], axis=1)

disney2 = disney.drop(['pais','fecha_agregada','descripcion'], axis=1)

# %%
hulu2["plataforma"] = "hulu2"

# %%
hulu2.head()
# Out:
#   show_id   tipo                          titulo director  emitir  \
# 0      s1  Movie  Ricky Velez: Here's Everything      NaN     NaN
# 1      s2  Movie                    Silent Night      NaN     NaN
# 2      s3  Movie                    The Marksman      NaN     NaN
# 3      s4  Movie                            Gaia      NaN     NaN
# 4      s5  Movie                        Settlers      NaN     NaN
#
#    año_de_lanzamiento rating duracion                     genero plataforma
# 0                2021  TV-MA      NaN           Comedy, Stand Up      hulu2
# 1                2020    NaN   94 min     Crime, Drama, Thriller      hulu2
# 2                2021  PG-13  108 min           Action, Thriller      hulu2
# 3                2021      R   97 min                     Horror      hulu2
# 4                2021    NaN  104 min  Science Fiction, Thriller      hulu2

# %%
netflix2["plataforma"] = "netflix2"

# %%
netflix2.head()
# Out:
#   show_id     tipo                 titulo         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water             None
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans             None
# 4      s5  TV Show           Kota Factory             None
#
#                                               emitir  año_de_lanzamiento  \
# 0                                               None                2020
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...                2021
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...                2021
# 3                                               None                2021
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...                2021
#
#   rating   duracion                                             genero  \
# 0  PG-13     90 min                                      Documentaries
# 1  TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2  TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3  TV-MA   1 Season                             Docuseries, Reality TV
# 4  TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
#
#   plataforma
# 0   netflix2
# 1   netflix2
# 2   netflix2
# 3   netflix2
# 4   netflix2

# %%
amazon2["plataforma"] = "amazon2"

# %%
amazon2.head()
# Out:
#   show_id   tipo                titulo        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                               emitir  año_de_lanzamiento  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent                2014
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar                2018
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...                2017
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...                2014
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...                1989
#
#   rating duracion                   genero plataforma
# 0    NaN  113 min            Comedy, Drama    amazon2
# 1    13+  110 min     Drama, International    amazon2
# 2    NaN   74 min  Action, Drama, Suspense    amazon2
# 3    NaN   69 min              Documentary    amazon2
# 4    NaN   45 min           Drama, Fantasy    amazon2

# %%
disney2["plataforma"] = "disney2"

# %%
disney2.head()
# Out:
#   show_id     tipo                                            titulo  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                                NaN
#
#                                               emitir  año_de_lanzamiento  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...                2016
# 1           Jim Varney, Noelle Parker, Douglas Seale                1988
# 2  Raymond Albert Romano, John Leguizamo, Denis L...                2011
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...                2021
# 4  John Lennon, Paul McCartney, George Harrison, ...                2021
#
#   rating  duracion                         genero plataforma
# 0   TV-G    23 min              Animation, Family    disney2
# 1     PG    91 min                         Comedy    disney2
# 2   TV-G    23 min      Animation, Comedy, Family    disney2
# 3  TV-PG    41 min                        Musical    disney2
# 4    NaN  1 Season  Docuseries, Historical, Music    disney2

# %%
lista_de_hulu = hulu2["genero"].tolist()

# %%
df = pd.concat([netflix2, hulu2, disney2,amazon2])

# %%
df
# Out:
#      show_id     tipo                   titulo         director  \
# 0         s1    Movie     Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show            Blood & Water             None
# 2         s3  TV Show                Ganglands  Julien Leclercq
# 3         s4  TV Show    Jailbirds New Orleans             None
# 4         s5  TV Show             Kota Factory             None
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                  emitir  año_de_lanzamiento  \
# 0                                                  None                2020
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...                2021
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...                2021
# 3                                                  None                2021
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...                2021
# ...                                                 ...                 ...
# 9663                           Leo Gorcey, Bobby Jordan                1940
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...                2018
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...                2008
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...                2021
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...                2010
#
#      rating   duracion                                             genero  \
# 0     PG-13     90 min                                      Documentaries
# 1     TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2     TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3     TV-MA   1 Season                             Docuseries, Reality TV
# 4     TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
# ...     ...        ...                                                ...
# 9663     7+     60 min                                             Comedy
# 9664    13+  4 Seasons                                           TV Shows
# 9665      R     90 min                                             Action
# 9666  TV-MA   1 Season                                      Drama, Sports
# 9667      R    103 min                            Action, Drama, Suspense
#
#      plataforma
# 0      netflix2
# 1      netflix2
# 2      netflix2
# 3      netflix2
# 4      netflix2
# ...         ...
# 9663    amazon2
# 9664    amazon2
# 9665    amazon2
# 9666    amazon2
# 9667    amazon2
#
# [22998 rows x 10 columns]

# %%
data_all=pd.DataFrame([])
Lista_wrong=["min", "Seasons","Season"]
df_analysis= df[["show_id","rating","plataforma"]]

# %%
for elemento in Lista_wrong:
    
    # Filtrar el Dataframe por columna rating en el que se encuentre la palabra min, Seasons, Season
    df_analysis_filter= df_analysis.loc[df_analysis["rating"].str.contains(elemento, na=False)]
    data_all=pd.concat([data_all,df_analysis_filter])
    
data_all.rename(columns={'rating':"duracion"}, inplace=True)

# %%
#Sacamos las variables del dataframe principal
df_analysis_2= df[["show_id","duracion","plataforma"]]
df_analysis_2=df_analysis_2.dropna(subset="duracion")

# %%
#Juntamos las columnas
data_all=pd.concat([data_all, df_analysis_2])
data_all
# Out:
#      show_id duration plataforma   duracion
# 5541   s5542   74 min   netflix2        NaN
# 5794   s5795   84 min   netflix2        NaN
# 5813   s5814   66 min   netflix2        NaN
# 108     s109   93 min      hulu2        NaN
# 397     s398  136 min      hulu2        NaN
# ...      ...      ...        ...        ...
# 9663   s9664      NaN    amazon2     60 min
# 9664   s9665      NaN    amazon2  4 Seasons
# 9665   s9666      NaN    amazon2     90 min
# 9666   s9667      NaN    amazon2   1 Season
# 9667   s9668      NaN    amazon2    103 min
#
# [22831 rows x 4 columns]

# %%
#Limpieza de datos
data_all.rename(columns={'duration':"duration_2"}, inplace=True)

# %%
data_all["duration_2"]=data_all["duration_2"].str.replace(" min","")
data_all["duration_2"]=data_all["duration_2"].str.replace(" Seasons","")
data_all["duration_2"]=data_all["duration_2"].str.replace(" Season","")

# %%
#Juntamos todo en la tabla principal
df_final= pd.merge(df,data_all, on=["show_id","plataforma"],how="left")

df_final= df_final.drop_duplicates(subset=["titulo","tipo"])
df_final
# Out:
#       show_id     tipo                   titulo         director  \
# 0          s1    Movie     Dick Johnson Is Dead  Kirsten Johnson
# 1          s2  TV Show            Blood & Water             None
# 2          s3  TV Show                Ganglands  Julien Leclercq
# 3          s4  TV Show    Jailbirds New Orleans             None
# 4          s5  TV Show             Kota Factory             None
# ...       ...      ...                      ...              ...
# 23328   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 23329   s9665  TV Show            Planet Patrol              NaN
# 23330   s9666    Movie                  Outpost     Steve Barker
# 23331   s9667  TV Show  Maradona: Blessed Dream              NaN
# 23332   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                   emitir  año_de_lanzamiento  \
# 0                                                   None                2020
# 1      Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...                2021
# 2      Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...                2021
# 3                                                   None                2021
# 4      Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...                2021
# ...                                                  ...                 ...
# 23328                           Leo Gorcey, Bobby Jordan                1940
# 23329  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...                2018
# 23330  Ray Stevenson, Julian Wadham, Richard Brake, M...                2008
# 23331  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...                2021
# 23332  Michael Caine, Emily Mortimer, Joseph Gilgun, ...                2010
#
#       rating duracion_x                                             genero  \
# 0      PG-13     90 min                                      Documentaries
# 1      TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2      TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3      TV-MA   1 Season                             Docuseries, Reality TV
# 4      TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
# ...      ...        ...                                                ...
# 23328     7+     60 min                                             Comedy
# 23329    13+  4 Seasons                                           TV Shows
# 23330      R     90 min                                             Action
# 23331  TV-MA   1 Season                                      Drama, Sports
# 23332      R    103 min                            Action, Drama, Suspense
#
#       plataforma duration_2 duracion_y duracion_y
# 0       netflix2        NaN     90 min        NaN
# 1       netflix2        NaN  2 Seasons        NaN
# 2       netflix2        NaN   1 Season        NaN
# 3       netflix2        NaN   1 Season        NaN
# 4       netflix2        NaN  2 Seasons        NaN
# ...          ...        ...        ...        ...
# 23328    amazon2        NaN     60 min        NaN
# 23329    amazon2        NaN  4 Seasons        NaN
# 23330    amazon2        NaN     90 min        NaN
# 23331    amazon2        NaN   1 Season        NaN
# 23332    amazon2        NaN    103 min        NaN
#
# [22242 rows x 13 columns]

# %%
# Crear una conexion con MySQL

from sqlalchemy import create_engine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Alejandro\Downloads\Proyecto_individual_1\Descarga_de_datasets.ipynb Celda 34 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Alejandro/Downloads/Proyecto_individual_1/Descarga_de_datasets.ipynb#X45sZmlsZQ%3D%3D?line=0'>1</a> # Crear una conexion con MySQL
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alejandro/Downloads/Proyecto_individual_1/Descarga_de_datasets.ipynb#X45sZmlsZQ%3D%3D?line=2'>3</a> from sqlalchemy import create_engine
#
# ModuleNotFoundError: No module named 'sqlalchemy'
